# %% [markdown]
# <a href="https://colab.research.google.com/github/LitauD/dap-2024/blob/main/les01/rep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
